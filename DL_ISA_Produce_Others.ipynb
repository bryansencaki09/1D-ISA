# %%
import tensorflow as tf
print(tf.__version__)

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.backend import sigmoid
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, Dense, Dropout, LayerNormalization, Bidirectional, LSTM, GRU, Layer, SpatialDropout1D, GlobalAveragePooling1D
from tensorflow.keras.layers import Lambda, Reshape, Flatten, Input, MultiHeadAttention, Flatten, Concatenate, Add, Multiply, Embedding
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
# Out:
# 2025-12-21 17:49:29.389536: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.20.0

# %%
import torch
import pandas as pd
import os, math, random
random.seed(2)
import numpy as np
import tensorflow as tf
import pyrsgis
from pyrsgis import raster
from osgeo import gdal
import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Lambda, Reshape
from scipy import interpolate
from tensorflow.keras.optimizers import Adam
import rasterio
import gc

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
# # For MCTNet

# class PositionalEncoding(layers.Layer):
#     """
#     Standard sinusoidal positional encoding
#     """
#     def __init__(self, d_model, **kwargs):
#         super().__init__(**kwargs)
#         self.d_model = d_model
        
#     def get_positional_encoding(self, time_steps, d_model):
#         """Generate sinusoidal positional encoding"""
#         positions = tf.range(time_steps, dtype=tf.float32)[:, tf.newaxis]
#         dims = tf.range(d_model, dtype=tf.float32)[tf.newaxis, :]
        
#         angle_rates = 1 / tf.pow(10000.0, (2 * (dims // 2)) / tf.cast(d_model, tf.float32))
#         angle_rads = positions * angle_rates
        
#         sines = tf.sin(angle_rads[:, 0::2])
#         cosines = tf.cos(angle_rads[:, 1::2])
        
#         pos_encoding = tf.concat([sines, cosines], axis=-1)
#         if d_model % 2 != 0:
#             pos_encoding = pos_encoding[:, :-1]
            
#         return pos_encoding
    
#     def call(self, inputs):
#         batch_size = tf.shape(inputs)[0]
#         time_steps = tf.shape(inputs)[1]
        
#         pos_encoding = self.get_positional_encoding(time_steps, self.d_model)
#         pos_encoding = tf.expand_dims(pos_encoding, 0)
#         pos_encoding = tf.tile(pos_encoding, [batch_size, 1, 1])
        
#         return inputs + pos_encoding


# class TransformerSubModule(layers.Layer):
#     """
#     Transformer sub-module with multi-head self-attention
#     """
#     def __init__(self, d_model, num_heads, dropout_rate=0.1, **kwargs):
#         super().__init__(**kwargs)
#         self.d_model = d_model
#         self.num_heads = num_heads
#         self.dropout_rate = dropout_rate
        
#     def build(self, input_shape):
#         # Multi-head attention
#         self.mha = layers.MultiHeadAttention(
#             num_heads=self.num_heads,
#             key_dim=self.d_model // self.num_heads,
#             dropout=self.dropout_rate
#         )
        
#         # Feed-forward network
#         self.dense1 = layers.Dense(self.d_model * 4, activation='relu')
#         self.dropout_ffn1 = layers.Dropout(self.dropout_rate)
#         self.dense2 = layers.Dense(self.d_model)
        
#         # Layer normalization
#         self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
#         self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        
#         # Dropout
#         self.dropout1 = layers.Dropout(self.dropout_rate)
#         self.dropout2 = layers.Dropout(self.dropout_rate)
        
#         super().build(input_shape)
    
#     def call(self, inputs, training=None):
#         # Multi-head self-attention
#         attn_output = self.mha(inputs, inputs, training=training)
#         attn_output = self.dropout1(attn_output, training=training)
#         out1 = self.layernorm1(inputs + attn_output)
        
#         # Feed-forward network
#         ffn_output = self.dense1(out1)
#         ffn_output = self.dropout_ffn1(ffn_output, training=training)
#         ffn_output = self.dense2(ffn_output)
#         ffn_output = self.dropout2(ffn_output, training=training)
#         out2 = self.layernorm2(out1 + ffn_output)
        
#         return out2


# class CNNSubModule(layers.Layer):
#     """
#     CNN sub-module with 1D convolutions along time dimension
#     """
#     def __init__(self, filters, kernel_size=3, dropout_rate=0.1, **kwargs):
#         super().__init__(**kwargs)
#         self.filters = filters
#         self.kernel_size = kernel_size
#         self.dropout_rate = dropout_rate
        
#     def build(self, input_shape):
#         input_dim = input_shape[-1]
        
#         # Projection layer if input dimension doesn't match filters
#         if input_dim != self.filters:
#             self.projection = layers.Dense(self.filters)
#         else:
#             self.projection = None
        
#         # Two 1D convolutional layers
#         self.conv1 = layers.Conv1D(
#             filters=self.filters,
#             kernel_size=self.kernel_size,
#             padding='same'
#         )
#         self.bn1 = layers.BatchNormalization()
        
#         self.conv2 = layers.Conv1D(
#             filters=self.filters,
#             kernel_size=self.kernel_size,
#             padding='same'
#         )
#         self.bn2 = layers.BatchNormalization()
        
#         self.dropout = layers.Dropout(self.dropout_rate)
        
#         super().build(input_shape)
    
#     def call(self, inputs, training=None):
#         # Project inputs if needed for residual connection
#         residual = inputs
#         if self.projection is not None:
#             residual = self.projection(residual)
        
#         # First conv block
#         x = self.conv1(inputs)
#         x = self.bn1(x, training=training)
#         x = tf.nn.relu(x)
        
#         # Second conv block
#         x = self.conv2(x)
#         x = self.bn2(x, training=training)
        
#         # Residual connection
#         x = x + residual
#         x = tf.nn.relu(x)
#         x = self.dropout(x, training=training)
        
#         return x


# class CTFusionModule(layers.Layer):
#     """
#     CNN-Transformer Fusion Module
#     Combines CNN and Transformer sub-modules in parallel
#     """
#     def __init__(self, d_model, num_heads, kernel_size=3, 
#                  dropout_rate=0.1, add_pos_encoding=False, **kwargs):
#         super().__init__(**kwargs)
#         self.d_model = d_model
#         self.num_heads = num_heads
#         self.kernel_size = kernel_size
#         self.dropout_rate = dropout_rate
#         self.add_pos_encoding = add_pos_encoding
        
#     def build(self, input_shape):
#         input_dim = input_shape[-1]
        
#         # Project input to d_model if needed
#         if input_dim != self.d_model:
#             self.input_projection = layers.Dense(self.d_model)
#         else:
#             self.input_projection = None
        
#         # Positional encoding (only for first stage)
#         if self.add_pos_encoding:
#             self.pos_encoding = PositionalEncoding(d_model=self.d_model)
        
#         # CNN sub-module
#         self.cnn_module = CNNSubModule(
#             filters=self.d_model,
#             kernel_size=self.kernel_size,
#             dropout_rate=self.dropout_rate
#         )
        
#         # Transformer sub-module
#         self.transformer_module = TransformerSubModule(
#             d_model=self.d_model,
#             num_heads=self.num_heads,
#             dropout_rate=self.dropout_rate
#         )
        
#         super().build(input_shape)
    
#     def call(self, inputs, training=None):
#         x = inputs
        
#         # Project to d_model if needed
#         if self.input_projection is not None:
#             x = self.input_projection(x)
        
#         # Add positional encoding in first stage
#         if self.add_pos_encoding:
#             x = self.pos_encoding(x)
        
#         # Parallel processing through CNN and Transformer
#         cnn_features = self.cnn_module(x, training=training)
#         transformer_features = self.transformer_module(x, training=training)
        
#         # Concatenate features from both branches
#         fused_features = layers.Concatenate(axis=-1)([cnn_features, transformer_features])
        
#         return fused_features

# %%
# model_path = '/home/jupyter-bryan/ISA_Data/ISA_Citarum_Multi_Orig_MCTnet.keras'
# model = load_model(model_path,
#                    custom_objects={'PositionalEncoding': PositionalEncoding,
#                                    'TransformerSubModule': TransformerSubModule,
#                                    'CNNSubModule': CNNSubModule,
#                                    'CTFusionModule': CTFusionModule},
#                    compile=False)

# Then recompile with your custom loss
# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss=MultiFocalLossSlopeElevationConstraint(),
#     metrics=['accuracy'])z

# %%
# @keras.saving.register_keras_serializable()
# def ReshapeLayer(x):
#     shape = x.shape
#     reshape = Reshape((shape[1],shape[2]))(x)
#     return reshape

# %%
# model_path = '/home/jupyter-bryan/ISA_Data/ISA_Citarum_Multi_Orig_1D_Wonosobo_FineTune.keras'
# model = load_model(model_path, custom_objects={'ReshapeLayer': ReshapeLayer}, compile=False)

# %%
model = load_model('/home/jupyter-bryan/ISA_Data/ISA_Citarum_Multi_Orig_1DConus_FineTune.keras')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766310573.794507 2867471 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1089 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# # Load the saved model
# model_path = '/home/jupyter-bryan/ISA_Data/ISA_Citarum_Multi_Orig.keras'

# model = load_model(model_path,
#                    custom_objects={'MultiFocalLossSlopeElevationConstraint': MultiFocalLossSlopeElevationConstraint},
#                    compile=False)

# Load a new multispectral image
ds_ndvi, img_ndvi  = raster.read('/home/jupyter-bryan/ISA_Data/Raster/PH_3-Month_NDVI_2019_2024.tif')
ds_mndwi, img_mndwi  = raster.read('/home/jupyter-bryan/ISA_Data/Raster/PH_3-Month_MNDWI_2019_2024.tif')
ds_ndbi, img_ndbi  = raster.read('/home/jupyter-bryan/ISA_Data/Raster/PH_3-Month_NDBI_2019_2024.tif')
ds_ndbsi, img_ndbsi  = raster.read('/home/jupyter-bryan/ISA_Data/Raster/PH_3-Month_NDBSI_2019_2024.tif')
ds_cbi, img_cbi  = raster.read('/home/jupyter-bryan/ISA_Data/Raster/PH_3-Month_CBI_2019_2024.tif')
ds_uci, img_uci  = raster.read('/home/jupyter-bryan/ISA_Data/Raster/PH_3-Month_UCI_2019_2024.tif')

print(img_ndvi.shape)
print(img_mndwi.shape)
print(img_ndbi.shape)
print(img_ndbsi.shape)
print(img_cbi.shape)
print(img_uci.shape)
# Out:
# Warning 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed
# Warning 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed
# Warning 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed
# Warning 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed
# Warning 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed
# (24, 1973, 2560)
# (24, 1973, 2560)
# (24, 1973, 2560)
# (24, 1973, 2560)
# (24, 1973, 2560)
# (24, 1973, 2560)
# Warning 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed

# %%
img_ndvi_reshape = img_ndvi.reshape(img_ndvi.shape[0],(img_ndvi.shape[1]*img_ndvi.shape[2])).T
img_mndwi_reshape = img_mndwi.reshape(img_mndwi.shape[0],(img_mndwi.shape[1]*img_mndwi.shape[2])).T
img_ndbi_reshape = img_ndbi.reshape(img_ndbi.shape[0],(img_ndbi.shape[1]*img_ndbi.shape[2])).T
img_ndbsi_reshape = img_ndbsi.reshape(img_ndbsi.shape[0],(img_ndbsi.shape[1]*img_ndbsi.shape[2])).T
img_cbi_reshape = img_cbi.reshape(img_cbi.shape[0],(img_cbi.shape[1]*img_cbi.shape[2])).T
img_uci_reshape = img_uci.reshape(img_uci.shape[0],(img_uci.shape[1]*img_uci.shape[2])).T

# %%
def clean_and_interpolate(data):
    df = pd.DataFrame(data, dtype=np.float32) 
    df.dropna(how='all')
    
    if len(df) > 100000:  
        print(f"Processing large dataset with {len(df):,} pixels in chunks...")
        chunk_size = 50000
        results = []
        for i in range(0, len(df), chunk_size):
            chunk = df.iloc[i:i+chunk_size].copy()
            chunk_linear = chunk.interpolate(method='linear', limit_direction='both', axis=1, limit=None)
            chunk_final = chunk_linear.interpolate(method='spline', order=3, axis=1).fillna(method='ffill', axis=1).fillna(method='bfill', axis=1)
            chunk_clipped = chunk_final.clip(-1e6, 1e6)
            results.append(chunk_clipped.values.astype(np.float32))
            print(f"Processed chunk {i//chunk_size + 1}/{(len(df)-1)//chunk_size + 1}")
            gc.collect()
        valid_result = np.vstack(results)
    else:
        df_linear = df.interpolate(method='linear', limit_direction='both', axis=1, limit=None)
        df_final = df_linear.interpolate(method='spline', order=3, axis=1).fillna(method='ffill', axis=1).fillna(method='bfill', axis=1)
        valid_result = df_final.clip(-1e6, 1e6).values.astype(np.float32)

    return valid_result

# %%
# %%time
print("\n=== Interpolating NDVI ===")
img_ndvi_int = clean_and_interpolate(img_ndvi_reshape)

print("\n=== Interpolating MNDWI ===")
img_mndwi_int = clean_and_interpolate(img_mndwi_reshape)

print("\n=== Interpolating NDBI ===")
img_ndbi_int = clean_and_interpolate(img_ndbi_reshape)

print("\n=== Interpolating NDBSI ===")
img_ndbsi_int = clean_and_interpolate(img_ndbsi_reshape)

print("\n=== Interpolating CBI ===")
img_cbi_int = clean_and_interpolate(img_cbi_reshape)

print("\n=== Interpolating UCI ===")
img_uci_int = clean_and_interpolate(img_uci_reshape)
# Out:
# === Interpolating NDVI ===
# Processing large dataset with 5,050,880 pixels in chunks...
# Processed chunk 1/102
del img_ndvi_int, img_mndwi_int, img_ndbi_int, img_ndbsi_int, img_cbi_int, img_uci_int
del img_ndvi_reshape, img_mndwi_reshape, img_ndbi_reshape, img_ndbsi_reshape, img_cbi_reshape, img_uci_reshape
del comb_all
gc.collect()
# Out:
# Stacking all bands...
# Final input shape: (5050880, 24, 6)
# 0

# %%
# BATCH PREDICTION - Process in smaller chunks to avoid memory issues
def predict_in_batches(model, data, batch_size=5000):
    """Predict data in batches to manage memory"""
    n_samples = data.shape[0]
    predictions = []
    
    print(f"Predicting {n_samples:,} pixels in batches of {batch_size:,}...")
    
    for i in range(0, n_samples, batch_size):
        end_idx = min(i + batch_size, n_samples)
        batch = data[i:end_idx]
        batch = np.asarray(batch, dtype=np.float32)
        
        try:
            batch_pred = model.predict(batch, verbose=0)
            predictions.append(batch_pred)
            print(f"Processed batch {i//batch_size + 1}/{(n_samples-1)//batch_size + 1}")
        except Exception as e:
            print(f"Error in batch {i//batch_size + 1}: {e}")
            # Try with smaller batch size
            smaller_batch_size = batch_size // 2
            print(f"Retrying with smaller batch size: {smaller_batch_size}")
            for j in range(i, end_idx, smaller_batch_size):
                small_end = min(j + smaller_batch_size, end_idx)
                small_batch = data[j:small_end]
                small_batch = np.asarray(small_batch, dtype=np.float32)
                small_pred = model.predict(small_batch, verbose=0)
                predictions.append(small_pred)
        
        tf.keras.backend.clear_session()
        gc.collect()
    
    return np.vstack(predictions)

# %%
# %%time
# Perform prediction
print("Starting prediction...")
try:
    pred_ = predict_in_batches(model, comb_all_reshape, batch_size=2000)
    
except Exception as e:
    print(f"Error during prediction: {e}")
    print("Trying with even smaller batch size...")
    try:
        pred_ = predict_in_batches(model, comb_all_reshape, batch_size=1000)
    except Exception as e2:
        print(f"Still getting error: {e2}")
        print("Trying CPU-only prediction...")
        with tf.device('/CPU:0'):
            pred_ = predict_in_batches(model, comb_all_reshape, batch_size=1000)

print("Processing predictions...")
lc_pred_ = pred_.argmax(axis=1)

# Reshape back to image dimensions
img_pred = np.reshape(lc_pred_, (ds_ndvi.RasterYSize, ds_ndvi.RasterXSize))

print(f"Prediction shape: {img_pred.shape}")
print(f"Prediction min: {img_pred.min()}, max: {img_pred.max()}")
print(f"Unique classes: {np.unique(img_pred)}")

# Export result
outFile = r'/home/jupyter-bryan/ISA_Data/Raster_02/ISA_PH_Multi_Orig_1DConus_FineTune.tif'
raster.export(img_pred, ds_ndvi, filename=outFile, dtype='int')
print(f"Prediction saved to: {outFile}")
# Out:
# Starting prediction...
# Predicting 5,050,880 pixels in batches of 2,000...
# 2025-12-21 18:15:43.431886: I external/local_xla/xla/service/service.cc:163] XLA service 0x794e38004a40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-21 18:15:43.431914: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2025-12-21 18:15:43.452333: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-21 18:15:43.578214: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# I0000 00:00:1766312145.648510 2869798 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Processed batch 1/2526
# Processed batch 2/2526
# Processed batch 3/2526
# Processed batch 4/2526
# Processed batch 5/2526
# Processed batch 6/2526
# Processed batch 7/2526
# Processed batch 8/2526
# Processed batch 9/2526
# Processed batch 10/2526
# Processed batch 11/2526
# Processed batch 12/2526
# Processed batch 13/2526
# Processed batch 14/2526
# Processed batch 15/2526
# Processed batch 16/2526
# Processed batch 17/2526
# Processed batch 18/2526
# Processed batch 19/2526
# Processed batch 20/2526
# Processed batch 21/2526
# Processed batch 22/2526
# Processed batch 23/2526
# Processed batch 24/2526
# Processed batch 25/2526
# Processed batch 26/2526
# Processed batch 27/2526
# Processed batch 28/2526
# Processed batch 29/2526
# Processed batch 30/2526
# Processed batch 31/2526
# Processed batch 32/2526
# Processed batch 33/2526
# Processed batch 34/2526
# Processed batch 35/2526
# Processed batch 36/2526
# Processed batch 37/2526
# Processed batch 38/2526
# Processed batch 39/2526
# Processed batch 40/2526
# Processed batch 41/2526
# Processed batch 42/2526
# Processed batch 43/2526
# Processed batch 44/2526
# Processed batch 45/2526
# Processed batch 46/2526
# Processed batch 47/2526
# Processed batch 48/2526
# Processed batch 49/2526
# Processed batch 50/2526
# Processed batch 51/2526
# Processed batch 52/2526
# Processed batch 53/2526
# Processed batch 54/2526
# Processed batch 55/2526
# Processed batch 56/2526
# Processed batch 57/2526
# Processed batch 58/2526
# Processed batch 59/2526
# Processed batch 60/2526
# Processed batch 61/2526
# Processed batch 62/2526
# Processed batch 63/2526
# Processed batch 64/2526
# Processed batch 65/2526
# Processed batch 66/2526
# Processed batch 67/2526
# Processed batch 68/2526
# Processed batch 69/2526
# Processed batch 70/2526
# Processed batch 71/2526
# Processed batch 72/2526
# Processed batch 73/2526
# Processed batch 74/2526
# Processed batch 75/2526
# Processed batch 76/2526
# Processed batch 77/2526
# Processed batch 78/2526
# Processed batch 79/2526
# Processed batch 80/2526
# Processed batch 81/2526
# Processed batch 82/2526
# Processed batch 83/2526
# Processed batch 84/2526
# Processed batch 85/2526
# Processed batch 86/2526
# Processed batch 87/2526
# Processed batch 88/2526
# Processed batch 89/2526
# Processed batch 90/2526
# Processed batch 91/2526
# Processed batch 92/2526
# Processed batch 93/2526
# Processed batch 94/2526
# Processed batch 95/2526
# Processed batch 96/2526
# Processed batch 97/2526
# Processed batch 98/2526
# Processed batch 99/2526
# Processed batch 100/2526
# Processed batch 101/2526
# Processed batch 102/2526
# Processed batch 103/2526
# Processed batch 104/2526
# Processed batch 105/2526
# Processed batch 106/2526
# Processed batch 107/2526
# Processed batch 108/2526
# Processed batch 109/2526
# Processed batch 110/2526
# Processed batch 111/2526
# Processed batch 112/2526
# Processed batch 113/2526
# Processed batch 114/2526
# Processed batch 115/2526
# Processed batch 116/2526
# Processed batch 117/2526
# Processed batch 118/2526
# Processed batch 119/2526
# Processed batch 120/2526
# Processed batch 121/2526
# Processed batch 122/2526
# Processed batch 123/2526
# Processed batch 124/2526
# Processed batch 125/2526
# Processed batch 126/2526
# Processed batch 127/2526
# Processed batch 128/2526
# Processed batch 129/2526
# Processed batch 130/2526
# Processed batch 131/2526
# Processed batch 132/2526
# Processed batch 133/2526
# Processed batch 522/2526
# Processed batch 523/2526
# Processed batch 524/2526
# Processed batch 525/2526
# Processed batch 526/2526
# Processed batch 527/2526
# Processed batch 528/2526
# Processed batch 529/2526
# Processed batch 530/2526
# Processed batch 531/2526
# Processed batch 532/2526
# Processed batch 533/2526
# Processed batch 534/2526
# Processed batch 535/2526
# Processed batch 536/2526
# Processed batch 537/2526
# Processed batch 538/2526
# Processed batch 539/2526
# Processed batch 540/2526
# Processed batch 541/2526
# Processed batch 542/2526
# Processed batch 543/2526
# Processed batch 544/2526
# Processed batch 545/2526
# Processed batch 546/2526
# Processed batch 547/2526
# Processed batch 548/2526
# Processed batch 549/2526
# Processed batch 550/2526
# Processed batch 551/2526
# Processed batch 552/2526
# Processed batch 553/2526
# Processed batch 554/2526
# Processed batch 555/2526
# Processed batch 556/2526
# Processed batch 557/2526
# Processed batch 558/2526
# Processed batch 559/2526
# Processed batch 560/2526
# Processed batch 561/2526
# Processed batch 562/2526
# Processed batch 563/2526
# Processed batch 564/2526
# Processed batch 565/2526
# Processed batch 566/2526
# Processed batch 567/2526
# Processed batch 568/2526
# Processed batch 569/2526
# Processed batch 570/2526
# Processed batch 571/2526
# Processed batch 572/2526
# Processed batch 573/2526
# Processed batch 574/2526
# Processed batch 575/2526
# Processed batch 576/2526
# Processed batch 577/2526
# Processed batch 578/2526
# Processed batch 579/2526
# Processed batch 580/2526
# Processed batch 581/2526
# Processed batch 582/2526
# Processed batch 583/2526
# Processed batch 584/2526
# Processed batch 585/2526
# Processed batch 586/2526
# Processed batch 587/2526
# Processed batch 588/2526
# Processed batch 589/2526
# Processed batch 590/2526
# Processed batch 591/2526
# Processed batch 592/2526
# Processed batch 593/2526
# Processed batch 594/2526
# Processed batch 595/2526
# Processed batch 596/2526
# Processed batch 597/2526
# Processed batch 598/2526
# Processed batch 599/2526
# Processed batch 600/2526
# Processed batch 601/2526
# Processed batch 602/2526
# Processed batch 603/2526
# Processed batch 604/2526
# Processed batch 605/2526
# Processed batch 606/2526
# Processed batch 607/2526
# Processed batch 608/2526
# Processed batch 609/2526
# Processed batch 610/2526
# Processed batch 611/2526
# Processed batch 612/2526
# Processed batch 613/2526
# Processed batch 614/2526
# Processed batch 615/2526
# Processed batch 616/2526
# Processed batch 617/2526
# Processed batch 618/2526
# Processed batch 619/2526
# Processed batch 620/2526
# Processed batch 621/2526
# Processed batch 622/2526
# Processed batch 623/2526
# Processed batch 624/2526
# Processed batch 625/2526
# Processed batch 626/2526
# Processed batch 627/2526
# Processed batch 628/2526
# Processed batch 629/2526
# Processed batch 630/2526
# Processed batch 631/2526
# Processed batch 632/2526
# Processed batch 633/2526
# Processed batch 634/2526
# Processed batch 635/2526
# Processed batch 636/2526
# Processed batch 637/2526
# Processed batch 638/2526
# Processed batch 639/2526
# Processed batch 640/2526
# Processed batch 641/2526
# Processed batch 642/2526
# Processed batch 643/2526
# Processed batch 644/2526
# Processed batch 645/2526
# Processed batch 646/2526
# Processed batch 647/2526
# Processed batch 648/2526
# Processed batch 649/2526
# Processed batch 650/2526
# Processed batch 651/2526
# Processed batch 781/2526
# Processed batch 782/2526
# Processed batch 783/2526
# Processed batch 784/2526
# Processed batch 785/2526
# Processed batch 786/2526
# Processed batch 787/2526
# Processed batch 788/2526
# Processed batch 789/2526
# Processed batch 790/2526
# Processed batch 791/2526
# Processed batch 792/2526
# Processed batch 793/2526
# Processed batch 794/2526
# Processed batch 795/2526
# Processed batch 796/2526
# Processed batch 797/2526
# Processed batch 798/2526
# Processed batch 799/2526
# Processed batch 800/2526
# Processed batch 801/2526
# Processed batch 802/2526
# Processed batch 803/2526
# Processed batch 804/2526
# Processed batch 805/2526
# Processed batch 806/2526
# Processed batch 807/2526
# Processed batch 808/2526
# Processed batch 809/2526
# Processed batch 810/2526
# Processed batch 811/2526
# Processed batch 812/2526
# Processed batch 813/2526
# Processed batch 814/2526
# Processed batch 815/2526
# Processed batch 816/2526
# Processed batch 817/2526
# Processed batch 818/2526
# Processed batch 819/2526
# Processed batch 820/2526
# Processed batch 821/2526
# Processed batch 822/2526
# Processed batch 823/2526
# Processed batch 824/2526
# Processed batch 825/2526
# Processed batch 826/2526
# Processed batch 827/2526
# Processed batch 828/2526
# Processed batch 829/2526
# Processed batch 830/2526
# Processed batch 831/2526
# Processed batch 832/2526
# Processed batch 833/2526
# Processed batch 834/2526
# Processed batch 835/2526
# Processed batch 836/2526
# Processed batch 837/2526
# Processed batch 838/2526
# Processed batch 839/2526
# Processed batch 840/2526
# Processed batch 841/2526
# Processed batch 842/2526
# Processed batch 843/2526
# Processed batch 844/2526
# Processed batch 845/2526
# Processed batch 846/2526
# Processed batch 847/2526
# Processed batch 848/2526
# Processed batch 849/2526
# Processed batch 850/2526
# Processed batch 851/2526
# Processed batch 852/2526
# Processed batch 853/2526
# Processed batch 854/2526
# Processed batch 855/2526
# Processed batch 856/2526
# Processed batch 857/2526
# Processed batch 858/2526
# Processed batch 859/2526
# Processed batch 860/2526
# Processed batch 861/2526
# Processed batch 862/2526
# Processed batch 863/2526
# Processed batch 864/2526
# Processed batch 865/2526
# Processed batch 866/2526
# Processed batch 867/2526
# Processed batch 868/2526
# Processed batch 869/2526
# Processed batch 870/2526
# Processed batch 871/2526
# Processed batch 872/2526
# Processed batch 873/2526
# Processed batch 874/2526
# Processed batch 875/2526
# Processed batch 876/2526
# Processed batch 877/2526
# Processed batch 878/2526
# Processed batch 879/2526
# Processed batch 880/2526
# Processed batch 881/2526
# Processed batch 882/2526
# Processed batch 883/2526
# Processed batch 884/2526
# Processed batch 885/2526
# Processed batch 886/2526
# Processed batch 887/2526
# Processed batch 888/2526
# Processed batch 889/2526
# Processed batch 890/2526
# Processed batch 891/2526
# Processed batch 892/2526
# Processed batch 893/2526
# Processed batch 894/2526
# Processed batch 895/2526
# Processed batch 896/2526
# Processed batch 897/2526
# Processed batch 898/2526
# Processed batch 899/2526
# Processed batch 900/2526
# Processed batch 901/2526
# Processed batch 902/2526
# Processed batch 903/2526
# Processed batch 904/2526
# Processed batch 905/2526
# Processed batch 906/2526
# Processed batch 907/2526
# Processed batch 908/2526
# Processed batch 909/2526
# Processed batch 910/2526
# Processed batch 1945/2526
# Processed batch 1946/2526
# Processed batch 1947/2526
# Processed batch 1948/2526
# Processed batch 1949/2526
# Processed batch 1950/2526
# Processed batch 1951/2526
# Processed batch 1952/2526
# Processed batch 1953/2526
# Processed batch 1954/2526
# Processed batch 1955/2526
# Processed batch 1956/2526
# Processed batch 1957/2526
# Processed batch 1958/2526
# Processed batch 1959/2526
# Processed batch 1960/2526
# Processed batch 1961/2526
# Processed batch 1962/2526
# Processed batch 1963/2526
# Processed batch 1964/2526
# Processed batch 1965/2526
# Processed batch 1966/2526
# Processed batch 1967/2526
# Processed batch 1968/2526
# Processed batch 1969/2526
# Processed batch 1970/2526
# Processed batch 1971/2526
# Processed batch 1972/2526
# Processed batch 1973/2526
# Processed batch 1974/2526
# Processed batch 1975/2526
# Processed batch 1976/2526
# Processed batch 1977/2526
# Processed batch 1978/2526
# Processed batch 1979/2526
# Processed batch 1980/2526
# Processed batch 1981/2526
# Processed batch 1982/2526
# Processed batch 1983/2526
# Processed batch 1984/2526
# Processed batch 1985/2526
# Processed batch 1986/2526
# Processed batch 1987/2526
# Processed batch 1988/2526
# Processed batch 1989/2526
# Processed batch 1990/2526
# Processed batch 1991/2526
# Processed batch 1992/2526
# Processed batch 1993/2526
# Processed batch 1994/2526
# Processed batch 1995/2526
# Processed batch 1996/2526
# Processed batch 1997/2526
# Processed batch 1998/2526
# Processed batch 1999/2526
# Processed batch 2000/2526
# Processed batch 2001/2526
# Processed batch 2002/2526
# Processed batch 2003/2526
# Processed batch 2004/2526
# Processed batch 2005/2526
# Processed batch 2006/2526
# Processed batch 2007/2526
# Processed batch 2008/2526
# Processed batch 2009/2526
# Processed batch 2010/2526
# Processed batch 2011/2526
# Processed batch 2012/2526
# Processed batch 2013/2526
# Processed batch 2014/2526
# Processed batch 2015/2526
# Processed batch 2016/2526
# Processed batch 2017/2526
# Processed batch 2018/2526
# Processed batch 2019/2526
# Processed batch 2020/2526
# Processed batch 2021/2526
# Processed batch 2022/2526
# Processed batch 2023/2526
# Processed batch 2024/2526
# Processed batch 2025/2526
# Processed batch 2026/2526
# Processed batch 2027/2526
# Processed batch 2028/2526
# Processed batch 2029/2526
# Processed batch 2030/2526
# Processed batch 2031/2526
# Processed batch 2032/2526
# Processed batch 2033/2526
# Processed batch 2034/2526
# Processed batch 2035/2526
# Processed batch 2036/2526
# Processed batch 2037/2526
# Processed batch 2038/2526
# Processed batch 2039/2526
# Processed batch 2040/2526
# Processed batch 2041/2526
# Processed batch 2042/2526
# Processed batch 2043/2526
# Processed batch 2044/2526
# Processed batch 2045/2526
# Processed batch 2046/2526
# Processed batch 2047/2526
# Processed batch 2048/2526
# Processed batch 2049/2526
# Processed batch 2050/2526
# Processed batch 2051/2526
# Processed batch 2052/2526
# Processed batch 2053/2526
# Processed batch 2054/2526
# Processed batch 2055/2526
# Processed batch 2056/2526
# Processed batch 2057/2526
# Processed batch 2058/2526
# Processed batch 2059/2526
# Processed batch 2060/2526
# Processed batch 2061/2526
# Processed batch 2062/2526
# Processed batch 2063/2526
# Processed batch 2064/2526
# Processed batch 2065/2526
# Processed batch 2066/2526
# Processed batch 2067/2526
# Processed batch 2068/2526
# Processed batch 2069/2526
# Processed batch 2070/2526
# Processed batch 2071/2526
# Processed batch 2072/2526
# Processed batch 2073/2526
# Processed batch 2074/2526
# Processed batch 2075/2526
# Processed batch 2076/2526
# Processed batch 2077/2526
# Processed batch 2078/2526
# Processed batch 2079/2526
# Processed batch 2080/2526
# Processed batch 2081/2526
# Processed batch 2082/2526
# Processed batch 2083/2526
# Processed batch 2084/2526
# Processed batch 2085/2526
# Processed batch 2086/2526
# Processed batch 2087/2526
# Processed batch 2088/2526
# Processed batch 2089/2526
# Processed batch 2090/2526
# Processed batch 2091/2526
# Processed batch 2092/2526
# Processed batch 2093/2526
# Processed batch 2094/2526
# Processed batch 2095/2526
# Processed batch 2096/2526
# Processed batch 2097/2526
# Processed batch 2098/2526
# Processed batch 2099/2526
# Processed batch 2100/2526
# Processed batch 2101/2526
# Processed batch 2102/2526
# Processed batch 2103/2526
# Processed batch 2104/2526
# Processed batch 2105/2526
# Processed batch 2106/2526
# Processed batch 2107/2526
# Processed batch 2108/2526
# Processed batch 2109/2526
# Processed batch 2110/2526
# Processed batch 2111/2526
# Processed batch 2112/2526
# Processed batch 2113/2526
# Processed batch 2114/2526
# Processed batch 2115/2526
# Processed batch 2116/2526
# Processed batch 2117/2526
# Processed batch 2118/2526
# Processed batch 2119/2526
# Processed batch 2120/2526
# Processed batch 2121/2526
# Processed batch 2122/2526
# Processed batch 2123/2526
# Processed batch 2124/2526
# Processed batch 2125/2526
# Processed batch 2126/2526
# Processed batch 2127/2526
# Processed batch 2128/2526
# Processed batch 2129/2526
# Processed batch 2130/2526
# Processed batch 2131/2526
# Processed batch 2132/2526
# Processed batch 2133/2526
# Processed batch 2134/2526
# Processed batch 2135/2526
# Processed batch 2136/2526
# Processed batch 2137/2526
# Processed batch 2138/2526
# Processed batch 2139/2526
# Processed batch 2140/2526
# Processed batch 2141/2526
# Processed batch 2142/2526
# Processed batch 2143/2526
# Processed batch 2144/2526
# Processed batch 2145/2526
# Processed batch 2146/2526
# Processed batch 2147/2526
# Processed batch 2148/2526
# Processed batch 2149/2526
# Processed batch 2150/2526
# Processed batch 2151/2526
# Processed batch 2152/2526
# Processed batch 2153/2526
# Processed batch 2154/2526
# Processed batch 2155/2526
# Processed batch 2156/2526
# Processed batch 2157/2526
# Processed batch 2158/2526
# Processed batch 2159/2526
# Processed batch 2160/2526
# Processed batch 2161/2526
# Processed batch 2162/2526
# Processed batch 2163/2526
# Processed batch 2164/2526
# Processed batch 2165/2526
# Processed batch 2166/2526
# Processed batch 2167/2526
# Processed batch 2168/2526
# Processed batch 2169/2526
# Processed batch 2170/2526
# Processed batch 2171/2526
# Processed batch 2172/2526
# Processed batch 2173/2526
# Processed batch 2174/2526
# Processed batch 2175/2526
# Processed batch 2176/2526
# Processed batch 2177/2526
# Processed batch 2178/2526
# Processed batch 2179/2526
# Processed batch 2180/2526
# Processed batch 2181/2526
# Processed batch 2182/2526
# Processed batch 2183/2526
# Processed batch 2184/2526
# Processed batch 2185/2526
# Processed batch 2186/2526
# Processed batch 2187/2526
# Processed batch 2188/2526
# Processed batch 2189/2526
# Processed batch 2190/2526
# Processed batch 2191/2526
# Processed batch 2192/2526
# Processed batch 2193/2526
# Processed batch 2194/2526
# Processed batch 2195/2526
# Processed batch 2196/2526
# Processed batch 2197/2526
# Processed batch 2198/2526
# Processed batch 2199/2526
# Processed batch 2200/2526
# Processed batch 2201/2526
# Processed batch 2202/2526
# Processed batch 2203/2526
# Processed batch 2204/2526
# Processed batch 2205/2526
# Processed batch 2206/2526
# Processed batch 2207/2526
# Processed batch 2208/2526
# Processed batch 2209/2526
# Processed batch 2210/2526
# Processed batch 2211/2526
# Processed batch 2212/2526
# Processed batch 2213/2526
# Processed batch 2214/2526
# Processed batch 2215/2526
# Processed batch 2216/2526
# Processed batch 2217/2526
# Processed batch 2218/2526
# Processed batch 2219/2526
# Processed batch 2220/2526
# Processed batch 2221/2526
# Processed batch 2222/2526
# Processed batch 2223/2526
# Processed batch 2224/2526
# Processed batch 2225/2526
# Processed batch 2226/2526
# Processed batch 2227/2526
# Processed batch 2228/2526
# Processed batch 2229/2526
# Processed batch 2230/2526
# Processed batch 2231/2526
# Processed batch 2232/2526
# Processed batch 2233/2526
# Processed batch 2234/2526
# Processed batch 2235/2526
# Processed batch 2236/2526
# Processed batch 2237/2526
# Processed batch 2238/2526
# Processed batch 2239/2526
# Processed batch 2240/2526
# Processed batch 2241/2526
# Processed batch 2242/2526
# Processed batch 2243/2526
# Processed batch 2244/2526
# Processed batch 2245/2526
# Processed batch 2246/2526
# Processed batch 2247/2526
# Processed batch 2248/2526
# Processed batch 2249/2526
# Processed batch 2250/2526
# Processed batch 2251/2526
# Processed batch 2252/2526
# Processed batch 2253/2526
# Processed batch 2254/2526
# Processed batch 2255/2526
# Processed batch 2256/2526
# Processed batch 2257/2526
# Processed batch 2258/2526
# Processed batch 2259/2526
# Processed batch 2260/2526
# Processed batch 2261/2526
# Processed batch 2262/2526
# Processed batch 2263/2526
# Processed batch 2264/2526
# Processed batch 2265/2526
# Processed batch 2266/2526
# Processed batch 2267/2526
# Processed batch 2268/2526
# Processed batch 2269/2526
# Processed batch 2270/2526
# Processed batch 2271/2526
# Processed batch 2272/2526
# Processed batch 2273/2526
# Processed batch 2274/2526
# Processed batch 2275/2526
# Processed batch 2276/2526
# Processed batch 2277/2526
# Processed batch 2278/2526
# Processed batch 2279/2526
# Processed batch 2280/2526
# Processed batch 2281/2526
# Processed batch 2282/2526
# Processed batch 2283/2526
# Processed batch 2284/2526
# Processed batch 2285/2526
# Processed batch 2286/2526
# Processed batch 2287/2526
# Processed batch 2288/2526
# Processed batch 2289/2526
# Processed batch 2290/2526
# Processed batch 2291/2526
# Processed batch 2292/2526
# Processed batch 2293/2526
# Processed batch 2294/2526
# Processed batch 2295/2526
# Processed batch 2296/2526
# Processed batch 2297/2526
# Processed batch 2298/2526
# Processed batch 2299/2526
# Processed batch 2300/2526
# Processed batch 2301/2526
# Processed batch 2302/2526
# Processed batch 2303/2526
# Processed batch 2304/2526
# Processed batch 2305/2526
# Processed batch 2306/2526
# Processed batch 2307/2526
# Processed batch 2308/2526
# Processed batch 2309/2526
# Processed batch 2310/2526
# Processed batch 2311/2526
# Processed batch 2312/2526
# Processed batch 2313/2526
# Processed batch 2314/2526
# Processed batch 2315/2526
# Processed batch 2316/2526
# Processed batch 2317/2526
# Processed batch 2318/2526
# Processed batch 2319/2526
# Processed batch 2320/2526
# Processed batch 2321/2526
# Processed batch 2322/2526
# Processed batch 2323/2526
# Processed batch 2324/2526
# Processed batch 2325/2526
# Processed batch 2326/2526
# Processed batch 2327/2526
# Processed batch 2328/2526
# Processed batch 2329/2526
# Processed batch 2330/2526
# Processed batch 2331/2526
# Processed batch 2332/2526
# Processed batch 2333/2526
# Processed batch 2334/2526
# Processed batch 2335/2526
# Processed batch 2336/2526
# Processed batch 2337/2526
# Processed batch 2338/2526
# Processed batch 2339/2526
# Processed batch 2340/2526
# Processed batch 2341/2526
# Processed batch 2342/2526
# Processed batch 2343/2526
# Processed batch 2344/2526
# Processed batch 2345/2526
# Processed batch 2346/2526
# Processed batch 2347/2526
# Processed batch 2348/2526
# Processed batch 2349/2526
# Processed batch 2350/2526
# Processed batch 2351/2526
# Processed batch 2352/2526
# Processed batch 2353/2526
# Processed batch 2354/2526
# Processed batch 2355/2526
# Processed batch 2356/2526
# Processed batch 2357/2526
# Processed batch 2358/2526
# Processed batch 2359/2526
# Processed batch 2360/2526
# Processed batch 2361/2526
# Processed batch 2362/2526
# Processed batch 2363/2526
# Processed batch 2364/2526
# Processed batch 2365/2526
# Processed batch 2366/2526
# Processed batch 2367/2526
# Processed batch 2368/2526
# Processed batch 2369/2526
# Processed batch 2370/2526
# Processed batch 2371/2526
# Processed batch 2372/2526
# Processed batch 2373/2526
# Processed batch 2374/2526
# Processed batch 2375/2526
# Processed batch 2376/2526
# Processed batch 2377/2526
# Processed batch 2378/2526
# Processed batch 2379/2526
# Processed batch 2380/2526
# Processed batch 2381/2526
# Processed batch 2382/2526
# Processed batch 2383/2526
# Processed batch 2384/2526
# Processed batch 2385/2526
# Processed batch 2386/2526
# Processed batch 2387/2526
# Processed batch 2388/2526
# Processed batch 2389/2526
# Processed batch 2390/2526
# Processed batch 2391/2526
# Processed batch 2392/2526
# Processed batch 2393/2526
# Processed batch 2394/2526
# Processed batch 2395/2526
# Processed batch 2396/2526
# Processed batch 2397/2526
# Processed batch 2398/2526
# Processed batch 2399/2526
# Processed batch 2400/2526
# Processed batch 2401/2526
# Processed batch 2402/2526
# Processed batch 2403/2526
# Processed batch 2404/2526
# Processed batch 2405/2526
# Processed batch 2406/2526
# Processed batch 2407/2526
# Processed batch 2408/2526
# Processed batch 2409/2526
# Processed batch 2410/2526
# Processed batch 2411/2526
# Processed batch 2412/2526
# Processed batch 2413/2526
# Processed batch 2414/2526
# Processed batch 2415/2526
# Processed batch 2416/2526
# Processed batch 2417/2526
# Processed batch 2418/2526
# Processed batch 2419/2526
# Processed batch 2420/2526
# Processed batch 2421/2526
# Processed batch 2422/2526
# Processed batch 2423/2526
# Processed batch 2424/2526
# Processed batch 2425/2526
# Processed batch 2426/2526
# Processed batch 2427/2526
# Processed batch 2428/2526
# Processed batch 2429/2526
# Processed batch 2430/2526
# Processed batch 2431/2526
# Processed batch 2432/2526
# Processed batch 2433/2526
# Processed batch 2434/2526
# Processed batch 2435/2526
# Processed batch 2436/2526
# Processed batch 2437/2526
# Processed batch 2438/2526
# Processed batch 2439/2526
# Processed batch 2440/2526
# Processed batch 2441/2526
# Processed batch 2442/2526
# Processed batch 2443/2526
# Processed batch 2444/2526
# Processed batch 2445/2526
# Processed batch 2446/2526
# Processed batch 2447/2526
# Processed batch 2448/2526
# Processed batch 2449/2526
# Processed batch 2450/2526
# Processed batch 2451/2526
# Processed batch 2452/2526
# Processed batch 2453/2526
# Processed batch 2454/2526
# Processed batch 2455/2526
# Processed batch 2456/2526
# Processed batch 2457/2526
# Processed batch 2458/2526
# Processed batch 2459/2526
# Processed batch 2460/2526
# Processed batch 2461/2526
# Processed batch 2462/2526
# Processed batch 2463/2526
# Processed batch 2464/2526
# Processed batch 2465/2526
# Processed batch 2466/2526
# Processed batch 2467/2526
# Processed batch 2468/2526
# Processed batch 2469/2526
# Processed batch 2470/2526
# Processed batch 2471/2526
# Processed batch 2472/2526
# Processed batch 2473/2526
# Processed batch 2474/2526
# Processed batch 2475/2526
# Processed batch 2476/2526
# Processed batch 2477/2526
# Processed batch 2478/2526
# Processed batch 2479/2526
# Processed batch 2480/2526
# Processed batch 2481/2526
# Processed batch 2482/2526
# Processed batch 2483/2526
# Processed batch 2484/2526
# Processed batch 2485/2526
# Processed batch 2486/2526
# Processed batch 2487/2526
# Processed batch 2488/2526
# Processed batch 2489/2526
# Processed batch 2490/2526
# Processed batch 2491/2526
# Processed batch 2492/2526
# Processed batch 2493/2526
# Processed batch 2494/2526
# Processed batch 2495/2526
# Processed batch 2496/2526
# Processed batch 2497/2526
# Processed batch 2498/2526
# Processed batch 2499/2526
# Processed batch 2500/2526
# Processed batch 2501/2526
# Processed batch 2502/2526
# Processed batch 2503/2526
# Processed batch 2504/2526
# Processed batch 2505/2526
# Processed batch 2506/2526
# Processed batch 2507/2526
# Processed batch 2508/2526
# Processed batch 2509/2526
# Processed batch 2510/2526
# Processed batch 2511/2526
# Processed batch 2512/2526
# Processed batch 2513/2526
# Processed batch 2514/2526
# Processed batch 2515/2526
# Processed batch 2516/2526
# Processed batch 2517/2526
# Processed batch 2518/2526
# Processed batch 2519/2526
# Processed batch 2520/2526
# Processed batch 2521/2526
# Processed batch 2522/2526
# Processed batch 2523/2526
# Processed batch 2524/2526
# Processed batch 2525/2526
# Processed batch 2526/2526
# Processing predictions...
# Prediction shape: (1973, 2560)
# Prediction min: 0, max: 4
# Unique classes: [0 1 2 3 4]
# Prediction saved to: /home/jupyter-bryan/ISA_Data/Raster_02/ISA_PH_Multi_Orig_1DConus_FineTune.tif
# CPU times: user 26min 41s, sys: 1min 1s, total: 27min 42s
# Wall time: 26min 40s
# ERROR 1: PROJ: proj_create_from_name: Open of /opt/tljh/user/share/proj failed
